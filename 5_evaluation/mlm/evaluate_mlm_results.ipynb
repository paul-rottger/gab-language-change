# %% [markdown]
# # EVALUATE TEST SET-LEVEL MLM RESULTS

# %%
import pandas as pd
import csv
import os
import re
import numpy as np

from scipy.stats import wilcoxon

# plotting
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import matplotlib.font_manager as font_manager
from matplotlib import colors

sns.set_theme()

# %% [markdown]
# ## Load data

# %%
# load txt files, each containing pseudoperplexity

perplexity = {}
directory = '../../0_results/mlm'
for dataset in os.listdir(directory):
    perplexity[dataset]={}
    for test_type in os.listdir(os.path.join(directory, dataset)):
        perplexity[dataset][test_type]={}
        for result_txt in os.listdir(os.path.join(directory, dataset, test_type)):
            if result_txt.endswith(".txt"):
                with open(os.path.join(directory, dataset, test_type, result_txt), 'r') as file:
                    perplexity[dataset][test_type][os.path.splitext(result_txt)[0]] = float(file.read().replace('\n', ''))

# %% [markdown]
# # Results on Random Test Set

# %%
def results_on_rand(DATASET):
    plot_df = pd.DataFrame.from_dict(perplexity[DATASET]["test-on-rand"], orient="index")
    
    plot_df.sort_index(inplace=True)
    plot_df.rename(columns={0:'pseudo-perplexity'}, inplace=True)
    plot_df.index.name="Model"
    
    cm = sns.color_palette('Greens_r', as_cmap=True)
    display(plot_df.style.background_gradient(cmap=cm, axis = 0 ).set_table_attributes('style="font-family: CMU Serif; font-size:16px"').format('{0:,.2f}'))

# %%
results_on_rand("reddit")
# Out:
# <style  type="text/css" >
# #T_e6c8b_row0_col0,#T_e6c8b_row1_col0,#T_e6c8b_row2_col0,#T_e6c8b_row3_col0,#T_e6c8b_row5_col0,#T_e6c8b_row34_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_e6c8b_row4_col0,#T_e6c8b_row6_col0,#T_e6c8b_row11_col0,#T_e6c8b_row15_col0,#T_e6c8b_row35_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_e6c8b_row7_col0,#T_e6c8b_row10_col0,#T_e6c8b_row13_col0,#T_e6c8b_row14_col0,#T_e6c8b_row19_col0,#T_e6c8b_row29_col0,#T_e6c8b_row32_col0,#T_e6c8b_row33_col0{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_e6c8b_row8_col0,#T_e6c8b_row9_col0,#T_e6c8b_row12_col0,#T_e6c8b_row16_col0,#T_e6c8b_row18_col0,#T_e6c8b_row20_col0,#T_e6c8b_row21_col0,#T_e6c8b_row22_col0,#T_e6c8b_row23_col0,#T_e6c8b_row24_col0,#T_e6c8b_row25_col0,#T_e6c8b_row26_col0,#T_e6c8b_row27_col0,#T_e6c8b_row28_col0,#T_e6c8b_row30_col0,#T_e6c8b_row31_col0{
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }#T_e6c8b_row17_col0{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_e6c8b_row36_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_e6c8b_row37_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e6c8b_row38_col0{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_e6c8b_row39_col0{
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }#T_e6c8b_row40_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }</style><table id="T_e6c8b_" style="font-family: CMU Serif; font-size:16px"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pseudo-perplexity</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6c8b_level0_row0" class="row_heading level0 row0" >bert-2017_03_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row0_col0" class="data row0 col0" >8.02</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row1" class="row_heading level0 row1" >bert-2017_04_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row1_col0" class="data row1 col0" >8.07</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row2" class="row_heading level0 row2" >bert-2017_05_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row2_col0" class="data row2 col0" >8.07</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row3" class="row_heading level0 row3" >bert-2017_06_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row3_col0" class="data row3 col0" >8.02</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row4" class="row_heading level0 row4" >bert-2017_07_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row4_col0" class="data row4 col0" >7.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row5" class="row_heading level0 row5" >bert-2017_08_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row5_col0" class="data row5 col0" >8.05</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row6" class="row_heading level0 row6" >bert-2017_09_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row6_col0" class="data row6 col0" >8.02</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row7" class="row_heading level0 row7" >bert-2017_10_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row7_col0" class="data row7 col0" >7.95</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row8" class="row_heading level0 row8" >bert-2017_11_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row8_col0" class="data row8 col0" >7.91</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row9" class="row_heading level0 row9" >bert-2017_12_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row9_col0" class="data row9 col0" >7.89</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row10" class="row_heading level0 row10" >bert-2018_01_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row10_col0" class="data row10 col0" >7.93</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row11" class="row_heading level0 row11" >bert-2018_02_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row11_col0" class="data row11 col0" >7.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row12" class="row_heading level0 row12" >bert-2018_03_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row12_col0" class="data row12 col0" >7.90</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row13" class="row_heading level0 row13" >bert-2018_04_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row13_col0" class="data row13 col0" >7.93</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row14" class="row_heading level0 row14" >bert-2018_05_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row14_col0" class="data row14 col0" >7.94</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row15" class="row_heading level0 row15" >bert-2018_06_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row15_col0" class="data row15 col0" >7.97</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row16" class="row_heading level0 row16" >bert-2018_07_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row16_col0" class="data row16 col0" >7.90</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row17" class="row_heading level0 row17" >bert-2018_08_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row17_col0" class="data row17 col0" >7.84</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row18" class="row_heading level0 row18" >bert-2018_09_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row18_col0" class="data row18 col0" >7.89</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row19" class="row_heading level0 row19" >bert-2018_10_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row19_col0" class="data row19 col0" >7.95</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row20" class="row_heading level0 row20" >bert-2018_11_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row20_col0" class="data row20 col0" >7.87</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row21" class="row_heading level0 row21" >bert-2018_12_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row21_col0" class="data row21 col0" >7.89</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row22" class="row_heading level0 row22" >bert-2019_01_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row22_col0" class="data row22 col0" >7.87</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row23" class="row_heading level0 row23" >bert-2019_02_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row23_col0" class="data row23 col0" >7.89</td>
#             </tr>
#             <tr>
#                         <th id="T_e6c8b_level0_row24" class="row_heading level0 row24" >bert-2019_03_1m-test_rand_10k</th>
#                         <td id="T_e6c8b_row24_col0" class="data row24

# %% [markdown]
# # Results on Monthly Test Sets: Absolute Values & Relative to Random Control Baseline

# %%
# helper function for diverging color palette
def background_gradient(s, m, M, cmap='BuPu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

def results_on_month(DATASET, BASELINE_MODEL="",
                     YEAR_FILTER = ["2017", "2018", "2019", "2020"],
                     MONTH_FILTER = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]):    
    
    result_dict = perplexity[DATASET]["politics-test"] #"test-on-month" / "politics-test"
    
    perpl_series = {}
    for model in sorted(pd.unique(pd.Series(result_dict.keys()).apply(lambda x: re.search(r'(.*?)-test(.*?)', x).group(1)))):
        if "bert-rand" not in model and "bert-base" not in model \
        and any(year in model for year in YEAR_FILTER) and any("_"+month in model for month in MONTH_FILTER):
            perpl_series[model] = {}
            for key in sorted(result_dict):
                if model in key and any("_"+year in re.search(r'(.*?)-test(.*)', key).group(2) for year in YEAR_FILTER) \
                and any("_"+month in re.search(r'(.*?)-test(.*)', key).group(2) for month in MONTH_FILTER):
                    perpl_series[model]["test" + re.search(r'(.*?)-test(.*)', key).group(2)] = result_dict[key]
    
    
    plot_df = pd.DataFrame.from_dict(perpl_series).reset_index().rename(columns={'index':'model'})
    plot_df.set_index('model', inplace=True)
    plot_df.index.name="Adapt."
    plot_df = plot_df.T
    
    cm = sns.color_palette('Greens_r', as_cmap=True)
    
    if BASELINE_MODEL!="":
        baseline_series = {}
        for key in sorted(result_dict):
                if BASELINE_MODEL in key:
                    baseline_series["test" + re.search(r'(.*?)-test(.*)', key).group(2)] = result_dict[key]
        for column in plot_df.columns: # divide by baseline model performance
            plot_df[column] = plot_df[column].divide(baseline_series[column])-1
        
        # format column names
        plot_df.columns = pd.Series(plot_df.columns).apply(lambda x: re.search("test_(.*?)_(.*?)_(.*)", x).group(1)[-2:] + "-" + re.search("test_(.*?)_(.*?)_(.*)", x).group(2))
        
        # format row names --> index
        for elem in plot_df.index:
            plot_df.rename(index={elem: re.search("bert-(.*?)_(.*?)_(.*)", elem).group(1)[-2:] + "-" + re.search("bert-(.*?)_(.*?)_(.*)", elem).group(2)}, inplace=True)
        
        # multiply by 100 to get pct values
        plot_df = plot_df.multiply(100)
        
        # define diverging color palette
        cm = sns.diverging_palette(250, 36, s=100, l=65, as_cmap=True)
        even_range = np.max([np.abs(plot_df.values.min()), np.abs(plot_df.values.max())])
        
        display(plot_df.style.apply(background_gradient,cmap=cm, m=-even_range, M=even_range)\
                .set_table_attributes('style="font-family: CMU Serif; font-size:26px"').set_precision(2))
    
    else:
        display(plot_df.style.background_gradient(cmap=cm, axis = 0 ).format('{0:,.2f}'))
        
    return plot_df

# %%
df = results_on_month("reddit", BASELINE_MODEL="bert-rand_1m", MONTH_FILTER = ["04", "08", "12"])
np.diag(df).mean()
# Out:
# <style  type="text/css" >
# #T_31205_row0_col0{
#             background-color:  #e1e9f4;
#         }#T_31205_row0_col1,#T_31205_row1_col0{
#             background-color:  #f2e7db;
#         }#T_31205_row0_col2,#T_31205_row7_col1,#T_31205_row7_col5{
#             background-color:  #f0c999;
#         }#T_31205_row0_col3{
#             background-color:  #eeb367;
#         }#T_31205_row0_col4{
#             background-color:  #ec9f3c;
#         }#T_31205_row0_col5{
#             background-color:  #eb8b0f;
#         }#T_31205_row0_col6{
#             background-color:  #ec9f3a;
#         }#T_31205_row0_col7{
#             background-color:  #eb8e17;
#         }#T_31205_row0_col8{
#             background-color:  #ea8400;
#         }#T_31205_row1_col1{
#             background-color:  #c2daf6;
#         }#T_31205_row1_col2{
#             background-color:  #f0cc9f;
#         }#T_31205_row1_col3{
#             background-color:  #eeba77;
#         }#T_31205_row1_col4,#T_31205_row6_col0{
#             background-color:  #f0cb9d;
#         }#T_31205_row1_col5{
#             background-color:  #ec992f;
#         }#T_31205_row1_col6{
#             background-color:  #eda446;
#         }#T_31205_row1_col7{
#             background-color:  #eeb469;
#         }#T_31205_row1_col8{
#             background-color:  #eb9424;
#         }#T_31205_row2_col0,#T_31205_row2_col4{
#             background-color:  #f1d4b2;
#         }#T_31205_row2_col1{
#             background-color:  #f2e9df;
#         }#T_31205_row2_col2{
#             background-color:  #d8e5f5;
#         }#T_31205_row2_col3{
#             background-color:  #f1ddc5;
#         }#T_31205_row2_col5{
#             background-color:  #efbf83;
#         }#T_31205_row2_col6{
#             background-color:  #efc692;
#         }#T_31205_row2_col7,#T_31205_row3_col7{
#             background-color:  #efbe81;
#         }#T_31205_row2_col8,#T_31205_row7_col2{
#             background-color:  #efc794;
#         }#T_31205_row3_col0,#T_31205_row5_col7{
#             background-color:  #f1dbc1;
#         }#T_31205_row3_col1,#T_31205_row5_col3,#T_31205_row8_col7{
#             background-color:  #f2e4d4;
#         }#T_31205_row3_col2,#T_31205_row8_col3{
#             background-color:  #f0cfa5;
#         }#T_31205_row3_col3{
#             background-color:  #d5e4f5;
#         }#T_31205_row3_col4,#T_31205_row5_col6{
#             background-color:  #f1dfc8;
#         }#T_31205_row3_col5{
#             background-color:  #efc288;
#         }#T_31205_row3_col6{
#             background-color:  #f0c997;
#         }#T_31205_row3_col8{
#             background-color:  #efc187;
#         }#T_31205_row4_col0{
#             background-color:  #f1dabf;
#         }#T_31205_row4_col1,#T_31205_row6_col8,#T_31205_row8_col6{
#             background-color:  #ebeef3;
#         }#T_31205_row4_col2{
#             background-color:  #eff0f3;
#         }#T_31205_row4_col3{
#             background-color:  #f2ebe3;
#         }#T_31205_row4_col4{
#             background-color:  #d1e2f5;
#         }#T_31205_row4_col5{
#             background-color:  #f2eae1;
#         }#T_31205_row4_col6,#T_31205_row4_col8{
#             background-color:  #f1d7b7;
#         }#T_31205_row4_col7{
#             background-color:  #f2e1ce;
#         }#T_31205_row5_col0,#T_31205_row5_col1{
#             background-color:  #f2e2d0;
#         }#T_31205_row5_col2{
#             background-color:  #f1e0ca;
#         }#T_31205_row5_col4{
#             background-color:  #f3f0ee;
#         }#T_31205_row5_col5{
#             background-color:  #d4e3f5;
#         }#T_31205_row5_col8{
#             background-color:  #f1d8b9;
#         }#T_31205_row6_col1,#T_31205_row6_col7{
#             background-color:  #f1dcc3;
#         }#T_31205_row6_col2{
#             background-color:  #f0d2ac;
#         }#T_31205_row6_col3,#T_31205_row7_col6,#T_31205_row8_col4{
#             background-color:  #f1d9bb;
#         }#T_31205_row6_col4{
#             background-color:  #f3ede8;
#         }#T_31205_row6_col5{
#             background-color:  #f2e5d7;
#         }#T_31205_row6_col6{
#             background-color:  #dee8f4;
#         }#T_31205_row7_col0{
#             background-color:  #eeb66f;
#         }#T_31205_row7_col3{
#             background-color:  #f1d4b0;
#         }#T_31205_row7_col4{
#             background-color:  #f0cea3;
#         }#T_31205_row7_col7{
#             background-color:  #eef0f3;
#         }#T_31205_row7_col8,#T_31205_row8_col5{
#             background-color:  #f1dabd;
#         }#T_31205_row8_col0{
#             background-color:  #f0ca9b;
#         }#T_31205_row8_col1{
#             background-color:  #f1dec6;
#         }#T_31205_row8_col2{
#             background-color:  #f1d5b4;
#         }#T_31205_row8_col8{
#             background-color:  #add0f8;
#         }</style><table id="T_31205_" style="font-family: CMU Serif; font-size:26px"><thead>    <tr>        <th class="index_name level0" >Adapt.</th>        <th class="col_heading level0 col0" >17-04</th>        <th class="col_heading level0 col1" >17-08</th>        <th class="col_heading level0 col2" >17-12</th>        <th class="col_heading level0 col3" >18-04</th>        <th class="col_heading level0 col4" >18-08</th>        <th class="col_heading level0 col5" >18-12</th>        <th class="col_heading level0 col6" >19-04</th>        <th class="col_heading level0 col7" >19-08</th>        <th class="col_heading level0 col8" >19-12</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_31205_level0_row0" class="row_heading level0 row0" >17-04</th>
#                         <td id="T_31205_row0_col0" class="data row0 col0" >-0.56</td>
#                         <td id="T_31205_row0_col1" class="data row0 col1" >0.53</td>
#                         <td id="T_31205_row0_col2" class="data row0 col2" >2.10</td>
#                         <td id="T_31205_row0_col3" class="data row0 col3" >3.24</td>
#                         <td id="T_31205_row0_col4" class="data row0 col4" >4.29</td>
#                         <td id="T_31205_row0_col5" class="data row0 col5" >5.37</td>
#                         <td id="T_31205_row0_col6" class="data row0 col6" >4.34</td>
#                         <td id="T_31205_row0_col7" class="data row0 col7" >5.19</td>
#                         <td id="T_31205_row0_col8" class="data row0 col8" >5.74</td>
#             </tr>
#             <tr>
#                         <th id="T_31205_level0_row1" class="row_heading level0 row1" >17-08</th>
#                         <td id="T_31205_row1_col0" class="data row1 col0" >0.52</td>
#                         <td id="T_31205_row1_col1" class="data row1 col1" >-1.62</td>
#                         <td id="T_31205_row1_col2" class="data row1 col2" >1.96</td>
#                         <td id="T_31205_row1_col3" class="data row1 col3" >2.89</td>
#                         <td id="T_31205_row1_col4" class="data row1 col4" >1.98</td>
#                         <td id="T_31205_row1_col5" class="data row1 col5" >4.58</td>
#                         <td id="T_31205_row1_col6" class="data row1 col6" >4.05</td>
#                         <td id="T_31205_row1_col7" class="data row1 col7" >3.20</td>
#                         <td id="T_31205_row1_col8" class="data row1 col8" >4.87</td>
#             </tr>
#             <tr>
#                         <th id="T_31205_level0_row2" class="row_heading level0 row2" >17-12</th>
#                         <td id="T_31205_row2_col0" class="data row2 col0" >1.48</td>
#                         <td id="T_31205_row2_col1" class="data row2 col1" >0.42</td>
#                         <td id="T_31205_row2_col2" class="data row2 col2" >-0.87</td>
#                         <td id="T_31205_row2_col3" class="data row2 col3" >1.05</td>
#                         <td id="T_31205_row2_col4" class="data row2 col4" >1.50</td>
#                         <td id="T_31205_row2_col5" class="data row2 col5" >2.61</td>
#                         <td id="T_31205_row2_col6" class="data row2 col6" >2.26</td>
#                         <td id="T_31205_row2_col7" class="data row2 col7" >2.65</td>
#                         <td id="T_31205_row2_col8" class="data row2 col8" >2.24</td>
#             </tr>
#             <tr>
# -1.0309416512516774

# %%
# test whether models perform better on past than on future

def wilcoxon_assymetry(df):
    
    x=np.empty(0)
    y=np.empty(0)
    
    for k in range(1,df.shape[0]):
        x = np.append(x, np.diag(df, k=k))
        y = np.append(y, np.diag(df, k=-k))
    
    dif = x-y
    print(dif.mean())
    
    return wilcoxon(x=x, y=y, alternative="greater")

wilcoxon_assymetry(df)
# Out:
# 0.7769864840908813
# WilcoxonResult(statistic=171004.0, pvalue=1.1873210639523903e-55)
