# %%
import pandas as pd
import csv
import os
import re

from scipy.stats import wilcoxon

# plotting
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import matplotlib.font_manager as font_manager

sns.set_theme()

# %% [markdown]
# ## Load data

# %%
# load txt files, each containing pseudoperplexity

perplexity = {}
directory = '../../0_results/mlm'
for dataset in os.listdir(directory):
    perplexity[dataset]={}
    for test_type in os.listdir(os.path.join(directory, dataset)):
        perplexity[dataset][test_type]={}
        for result_txt in os.listdir(os.path.join(directory, dataset, test_type)):
            if result_txt.endswith(".txt"):
                with open(os.path.join(directory, dataset, test_type, result_txt), 'r') as file:
                    perplexity[dataset][test_type][os.path.splitext(result_txt)[0]] = float(file.read().replace('\n', ''))

# %% [markdown]
# # Results on Random Test Set

# %%
def results_on_rand(DATASET):
    plot_df = pd.DataFrame.from_dict(perplexity[DATASET]["test-on-rand"], orient="index")
    
    plot_df.sort_index(inplace=True)
    plot_df.rename(columns={0:'pseudo-perplexity'}, inplace=True)
    plot_df.index.name="Model"
    
    cm = sns.color_palette('Greens_r', as_cmap=True)
    display(plot_df.style.background_gradient(cmap=cm, axis = 0 ).set_table_attributes('style="font-family: CMU Serif; font-size:16px"').format('{0:,.2f}'))

# %%
results_on_rand("gab")
# Out:
# <style  type="text/css" >
# #T_e2c2a_row0_col0{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_e2c2a_row1_col0,#T_e2c2a_row2_col0{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_e2c2a_row3_col0,#T_e2c2a_row7_col0,#T_e2c2a_row8_col0,#T_e2c2a_row9_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_e2c2a_row4_col0,#T_e2c2a_row5_col0,#T_e2c2a_row6_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_e2c2a_row10_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_e2c2a_row11_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e2c2a_row12_col0{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_e2c2a_row13_col0{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_e2c2a_row14_col0{
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }</style><table id="T_e2c2a_" style="font-family: CMU Serif; font-size:16px"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pseudo-perplexity</th>    </tr>    <tr>        <th class="index_name level0" >Model</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2c2a_level0_row0" class="row_heading level0 row0" >bert-01_1m-rand_10k</th>
#                         <td id="T_e2c2a_row0_col0" class="data row0 col0" >11.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row1" class="row_heading level0 row1" >bert-02_1m-rand_10k</th>
#                         <td id="T_e2c2a_row1_col0" class="data row1 col0" >11.77</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row2" class="row_heading level0 row2" >bert-03_1m-rand_10k</th>
#                         <td id="T_e2c2a_row2_col0" class="data row2 col0" >11.74</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row3" class="row_heading level0 row3" >bert-04_1m-rand_10k</th>
#                         <td id="T_e2c2a_row3_col0" class="data row3 col0" >11.64</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row4" class="row_heading level0 row4" >bert-05_1m-rand_10k</th>
#                         <td id="T_e2c2a_row4_col0" class="data row4 col0" >11.49</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row5" class="row_heading level0 row5" >bert-06_1m-rand_10k</th>
#                         <td id="T_e2c2a_row5_col0" class="data row5 col0" >11.51</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row6" class="row_heading level0 row6" >bert-07_1m-rand_10k</th>
#                         <td id="T_e2c2a_row6_col0" class="data row6 col0" >11.50</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row7" class="row_heading level0 row7" >bert-08_1m-rand_10k</th>
#                         <td id="T_e2c2a_row7_col0" class="data row7 col0" >11.61</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row8" class="row_heading level0 row8" >bert-09_1m-rand_10k</th>
#                         <td id="T_e2c2a_row8_col0" class="data row8 col0" >11.61</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row9" class="row_heading level0 row9" >bert-10_1m-rand_10k</th>
#                         <td id="T_e2c2a_row9_col0" class="data row9 col0" >11.65</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row10" class="row_heading level0 row10" >bert-base-rand_10k</th>
#                         <td id="T_e2c2a_row10_col0" class="data row10 col0" >36.15</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row11" class="row_heading level0 row11" >bert-rand-10m-rand_10k</th>
#                         <td id="T_e2c2a_row11_col0" class="data row11 col0" >7.91</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row12" class="row_heading level0 row12" >bert-rand-1m-rand_10k</th>
#                         <td id="T_e2c2a_row12_col0" class="data row12 col0" >11.12</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row13" class="row_heading level0 row13" >bert-rand-2m-rand_10k</th>
#                         <td id="T_e2c2a_row13_col0" class="data row13 col0" >10.14</td>
#             </tr>
#             <tr>
#                         <th id="T_e2c2a_level0_row14" class="row_heading level0 row14" >bert-rand-5m-rand_10k</th>
#                         <td id="T_e2c2a_row14_col0" class="data row14 col0" >8.94</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Results on Monthly Test Sets: Absolute Values & Relative to Random Control Baseline

# %%
# helper function for diverging color palette
def background_gradient(s, m, M, cmap='BuPu', low=0, high=0):
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = norm(s.values)
    c = [colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]

def results_on_month(DATASET, BASELINE_MODEL="",
                     YEAR_FILTER = ["2017", "2018", "2019", "2020"],
                     MONTH_FILTER = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]):    
    
    result_dict = perplexity[DATASET]["politics-test"] #"test-on-month" / "politics-test"
    
    perpl_series = {}
    for model in sorted(pd.unique(pd.Series(result_dict.keys()).apply(lambda x: re.search(r'(.*?)-test(.*?)', x).group(1)))):
        if "bert-rand" not in model and "bert-base" not in model \
        and any(year in model for year in YEAR_FILTER) and any("_"+month in model for month in MONTH_FILTER):
            perpl_series[model] = {}
            for key in sorted(result_dict):
                if model in key and any("_"+year in re.search(r'(.*?)-test(.*)', key).group(2) for year in YEAR_FILTER) \
                and any("_"+month in re.search(r'(.*?)-test(.*)', key).group(2) for month in MONTH_FILTER):
                    perpl_series[model]["test" + re.search(r'(.*?)-test(.*)', key).group(2)] = result_dict[key]
    
    
    plot_df = pd.DataFrame.from_dict(perpl_series).reset_index().rename(columns={'index':'model'})
    plot_df.set_index('model', inplace=True)
    plot_df.index.name="Adapt."
    plot_df = plot_df.T
    
    cm = sns.color_palette('Greens_r', as_cmap=True)
    
    if BASELINE_MODEL!="":
        baseline_series = {}
        for key in sorted(result_dict):
                if BASELINE_MODEL in key:
                    baseline_series["test" + re.search(r'(.*?)-test(.*)', key).group(2)] = result_dict[key]
        for column in plot_df.columns: # divide by baseline model performance
            plot_df[column] = plot_df[column].divide(baseline_series[column])-1
        
        # format column names
        plot_df.columns = pd.Series(plot_df.columns).apply(lambda x: re.search("test_(.*?)_(.*?)_(.*)", x).group(1)[-2:] + "-" + re.search("test_(.*?)_(.*?)_(.*)", x).group(2))
        
        # format row names --> index
        for elem in plot_df.index:
            plot_df.rename(index={elem: re.search("bert-(.*?)_(.*?)_(.*)", elem).group(1)[-2:] + "-" + re.search("bert-(.*?)_(.*?)_(.*)", elem).group(2)}, inplace=True)
        
        # multiply by 100 to get pct values
        plot_df = plot_df.multiply(100)
        
        # define diverging color palette
        cm = sns.diverging_palette(150, 10, as_cmap=True)
        even_range = np.max([np.abs(plot_df.values.min()), np.abs(plot_df.values.max())])

        
        display(plot_df.style.apply(background_gradient,cmap=cm, m=-even_range, M=even_range)\
                .set_table_attributes('style="font-family: CMU Serif; font-size:26px"').set_precision(2))
    
    else:
        display(plot_df.style.background_gradient(cmap=cm, axis = 0 ).format('{0:,.2f}'))
        
    return plot_df

# %%
df = results_on_month("gab", BASELINE_MODEL="bert-rand_1m")#, MONTH_FILTER = ["04", "08", "12"])
# Out:
# <style  type="text/css" >
# #T_e6b40_row0_col0{
#             background-color:  #b3cfc2;
#         }#T_e6b40_row0_col1,#T_e6b40_row2_col0{
#             background-color:  #efd9da;
#         }#T_e6b40_row0_col2,#T_e6b40_row2_col4,#T_e6b40_row5_col0,#T_e6b40_row8_col7{
#             background-color:  #ebbcbf;
#         }#T_e6b40_row0_col3,#T_e6b40_row5_col1,#T_e6b40_row6_col2{
#             background-color:  #eab2b6;
#         }#T_e6b40_row0_col4,#T_e6b40_row8_col3{
#             background-color:  #e6979d;
#         }#T_e6b40_row0_col5,#T_e6b40_row0_col8{
#             background-color:  #dd4f59;
#         }#T_e6b40_row0_col6,#T_e6b40_row8_col4{
#             background-color:  #e69399;
#         }#T_e6b40_row0_col7{
#             background-color:  #da3b46;
#         }#T_e6b40_row0_col9{
#             background-color:  #da3d49;
#         }#T_e6b40_row1_col0{
#             background-color:  #ebf2ee;
#         }#T_e6b40_row1_col1{
#             background-color:  #b6d1c5;
#         }#T_e6b40_row1_col2,#T_e6b40_row2_col3{
#             background-color:  #f1e5e6;
#         }#T_e6b40_row1_col3,#T_e6b40_row5_col2{
#             background-color:  #ecc3c6;
#         }#T_e6b40_row1_col4{
#             background-color:  #e9abaf;
#         }#T_e6b40_row1_col5{
#             background-color:  #dd545e;
#         }#T_e6b40_row1_col6{
#             background-color:  #e6989e;
#         }#T_e6b40_row1_col7{
#             background-color:  #dc4d58;
#         }#T_e6b40_row1_col8{
#             background-color:  #dd535d;
#         }#T_e6b40_row1_col9{
#             background-color:  #db4651;
#         }#T_e6b40_row2_col1{
#             background-color:  #f2eeee;
#         }#T_e6b40_row2_col2{
#             background-color:  #accbbd;
#         }#T_e6b40_row2_col5{
#             background-color:  #e06770;
#         }#T_e6b40_row2_col6,#T_e6b40_row6_col1{
#             background-color:  #e9acb1;
#         }#T_e6b40_row2_col7,#T_e6b40_row2_col8,#T_e6b40_row8_col5{
#             background-color:  #df6069;
#         }#T_e6b40_row2_col9{
#             background-color:  #de5a64;
#         }#T_e6b40_row3_col0{
#             background-color:  #eed1d3;
#         }#T_e6b40_row3_col1{
#             background-color:  #efd4d6;
#         }#T_e6b40_row3_col2{
#             background-color:  #e9f1ed;
#         }#T_e6b40_row3_col3{
#             background-color:  #a5c7b7;
#         }#T_e6b40_row3_col4,#T_e6b40_row4_col2,#T_e6b40_row5_col4{
#             background-color:  #f0e1e2;
#         }#T_e6b40_row3_col5{
#             background-color:  #e38289;
#         }#T_e6b40_row3_col6,#T_e6b40_row6_col3{
#             background-color:  #eab5b9;
#         }#T_e6b40_row3_col7{
#             background-color:  #e06b74;
#         }#T_e6b40_row3_col8,#T_e6b40_row4_col9{
#             background-color:  #e17179;
#         }#T_e6b40_row3_col9{
#             background-color:  #df646d;
#         }#T_e6b40_row4_col0{
#             background-color:  #edcacd;
#         }#T_e6b40_row4_col1{
#             background-color:  #eecfd1;
#         }#T_e6b40_row4_col3{
#             background-color:  #f2f1f1;
#         }#T_e6b40_row4_col4{
#             background-color:  #b9d3c7;
#         }#T_e6b40_row4_col5{
#             background-color:  #e79ca2;
#         }#T_e6b40_row4_col6{
#             background-color:  #edccce;
#         }#T_e6b40_row4_col7{
#             background-color:  #e2777f;
#         }#T_e6b40_row4_col8{
#             background-color:  #e37c84;
#         }#T_e6b40_row5_col3{
#             background-color:  #eecdcf;
#         }#T_e6b40_row5_col5{
#             background-color:  #e4eee8;
#         }#T_e6b40_row5_col6{
#             background-color:  #f2ebeb;
#         }#T_e6b40_row5_col7{
#             background-color:  #e38188;
#         }#T_e6b40_row5_col8{
#             background-color:  #e4838b;
#         }#T_e6b40_row5_col9,#T_e6b40_row7_col5{
#             background-color:  #e37b83;
#         }#T_e6b40_row6_col0{
#             background-color:  #eab0b5;
#         }#T_e6b40_row6_col4{
#             background-color:  #ebbdc1;
#         }#T_e6b40_row6_col5{
#             background-color:  #e79fa5;
#         }#T_e6b40_row6_col6{
#             background-color:  #b4d0c3;
#         }#T_e6b40_row6_col7{
#             background-color:  #e79ba1;
#         }#T_e6b40_row6_col8,#T_e6b40_row7_col1{
#             background-color:  #e79ea3;
#         }#T_e6b40_row6_col9,#T_e6b40_row9_col3,#T_e6b40_row9_col4{
#             background-color:  #e58f95;
#         }#T_e6b40_row7_col0,#T_e6b40_row8_col2{
#             background-color:  #e8a1a6;
#         }#T_e6b40_row7_col2{
#             background-color:  #e9a9ae;
#         }#T_e6b40_row7_col3{
#             background-color:  #e9a8ad;
#         }#T_e6b40_row7_col4{
#             background-color:  #eaafb3;
#         }#T_e6b40_row7_col6{
#             background-color:  #f0e0e1;
#         }#T_e6b40_row7_col7{
#             background-color:  #d6e5de;
#         }#T_e6b40_row7_col8{
#             background-color:  #f1e8e9;
#         }#T_e6b40_row7_col9{
#             background-color:  #ebbbbe;
#         }#T_e6b40_row8_col0,#T_e6b40_row9_col2{
#             background-color:  #e59097;
#         }#T_e6b40_row8_col1{
#             background-color:  #e6959b;
#         }#T_e6b40_row8_col6{
#             background-color:  #edc7ca;
#         }#T_e6b40_row8_col8{
#             background-color:  #87b4a0;
#         }#T_e6b40_row8_col9{
#             background-color:  #f2efef;
#         }#T_e6b40_row9_col0{
#             background-color:  #e69298;
#         }#T_e6b40_row9_col1{
#             background-color:  #e48990;
#         }#T_e6b40_row9_col5{
#             background-color:  #de5761;
#         }#T_e6b40_row9_col6{
#             background-color:  #ebb8bb;
#         }#T_e6b40_row9_col7{
#             background-color:  #e79a9f;
#         }#T_e6b40_row9_col8{
#             background-color:  #e0ebe5;
#         }#T_e6b40_row9_col9{
#             background-color:  #a2c5b5;
#         }</style><table id="T_e6b40_" style="font-family: CMU Serif; font-size:26px"><thead>    <tr>        <th class="index_name level0" >Adapt.</th>        <th class="col_heading level0 col0" >18-01</th>        <th class="col_heading level0 col1" >18-02</th>        <th class="col_heading level0 col2" >18-03</th>        <th class="col_heading level0 col3" >18-04</th>        <th class="col_heading level0 col4" >18-05</th>        <th class="col_heading level0 col5" >18-06</th>        <th class="col_heading level0 col6" >18-07</th>        <th class="col_heading level0 col7" >18-08</th>        <th class="col_heading level0 col8" >18-09</th>        <th class="col_heading level0 col9" >18-10</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6b40_level0_row0" class="row_heading level0 row0" >18-01</th>
#                         <td id="T_e6b40_row0_col0" class="data row0 col0" >-5.76</td>
#                         <td id="T_e6b40_row0_col1" class="data row0 col1" >2.48</td>
#                         <td id="T_e6b40_row0_col2" class="data row0 col2" >5.30</td>
#                         <td id="T_e6b40_row0_col3" class="data row0 col3" >6.22</td>
#                         <td id="T_e6b40_row0_col4" class="data row0 col4" >8.90</td>
#                         <td id="T_e6b40_row0_col5" class="data row0 col5" >15.89</td>
#                         <td id="T_e6b40_row0_col6" class="data row0 col6" >9.20</td>
#                         <td id="T_e6b40_row0_col7" class="data row0 col7" >17.98</td>
#                         <td id="T_e6b40_row0_col8" class="data row0 col8" >15.95</td>
#                         <td id="T_e6b40_row0_col9" class="data row0 col9" >17.57</td>
#             </tr>
#             <tr>
#                         <th id="T_e6b40_level0_row1" class="row_heading level0 row1" >18-02</th>
#                         <td id="T_e6b40_row1_col0" class="data row1 col0" >-0.21</td>
#                         <td id="T_e6b40_row1_col1" class="data row1 col1" >-5.53</td>
#                         <td id="T_e6b40_row1_col2" class="data row1 col2" >1.15</td>
#                         <td id="T_e6b40_row1_col3" class="data row1 col3" >4.53</td>
#                         <td id="T_e6b40_row1_col4" class="data row1 col4" >7.01</td>
#                         <t
# -5.676297445352968

# %%
df = results_on_month("reddit", BASELINE_MODEL="bert-rand_1m", MONTH_FILTER = ["04", "08", "12"])
np.diag(df).mean()
# Out:
# <style  type="text/css" >
# #T_81340_row0_col0{
#             background-color:  #dbe8e2;
#         }#T_81340_row0_col1,#T_81340_row1_col0{
#             background-color:  #f0e1e2;
#         }#T_81340_row0_col2,#T_81340_row7_col1,#T_81340_row7_col5{
#             background-color:  #eaafb3;
#         }#T_81340_row0_col3{
#             background-color:  #e48990;
#         }#T_81340_row0_col4{
#             background-color:  #e06871;
#         }#T_81340_row0_col5{
#             background-color:  #db4651;
#         }#T_81340_row0_col6{
#             background-color:  #e06770;
#         }#T_81340_row0_col7{
#             background-color:  #dc4c56;
#         }#T_81340_row0_col8{
#             background-color:  #da3b46;
#         }#T_81340_row1_col1{
#             background-color:  #bad4c8;
#         }#T_81340_row1_col2{
#             background-color:  #eab3b7;
#         }#T_81340_row1_col3{
#             background-color:  #e6959b;
#         }#T_81340_row1_col4,#T_81340_row6_col0{
#             background-color:  #eab2b6;
#         }#T_81340_row1_col5{
#             background-color:  #df5e68;
#         }#T_81340_row1_col6{
#             background-color:  #e16f78;
#         }#T_81340_row1_col7{
#             background-color:  #e58b91;
#         }#T_81340_row1_col8{
#             background-color:  #de5660;
#         }#T_81340_row2_col0,#T_81340_row2_col4{
#             background-color:  #ecc2c5;
#         }#T_81340_row2_col1{
#             background-color:  #f1e4e5;
#         }#T_81340_row2_col2{
#             background-color:  #d2e2da;
#         }#T_81340_row2_col3{
#             background-color:  #eed0d2;
#         }#T_81340_row2_col5{
#             background-color:  #e79ea3;
#         }#T_81340_row2_col6{
#             background-color:  #e9a9ae;
#         }#T_81340_row2_col7,#T_81340_row3_col7{
#             background-color:  #e79ca2;
#         }#T_81340_row2_col8,#T_81340_row7_col2{
#             background-color:  #e9abaf;
#         }#T_81340_row3_col0,#T_81340_row5_col7{
#             background-color:  #eecdcf;
#         }#T_81340_row3_col1,#T_81340_row5_col3,#T_81340_row8_col7{
#             background-color:  #efdbdd;
#         }#T_81340_row3_col2,#T_81340_row8_col3{
#             background-color:  #ebb8bb;
#         }#T_81340_row3_col3{
#             background-color:  #cfe1d8;
#         }#T_81340_row3_col4,#T_81340_row5_col6{
#             background-color:  #eed3d5;
#         }#T_81340_row3_col5{
#             background-color:  #e8a2a7;
#         }#T_81340_row3_col6{
#             background-color:  #e9aeb2;
#         }#T_81340_row3_col8{
#             background-color:  #e8a1a6;
#         }#T_81340_row4_col0{
#             background-color:  #edccce;
#         }#T_81340_row4_col1,#T_81340_row6_col8,#T_81340_row8_col6{
#             background-color:  #e7efeb;
#         }#T_81340_row4_col2{
#             background-color:  #ebf2ee;
#         }#T_81340_row4_col3{
#             background-color:  #f1e7e7;
#         }#T_81340_row4_col4{
#             background-color:  #cbded5;
#         }#T_81340_row4_col5{
#             background-color:  #f1e5e6;
#         }#T_81340_row4_col6,#T_81340_row4_col8{
#             background-color:  #edc6c9;
#         }#T_81340_row4_col7{
#             background-color:  #efd7d9;
#         }#T_81340_row5_col0,#T_81340_row5_col1{
#             background-color:  #efd9da;
#         }#T_81340_row5_col2{
#             background-color:  #efd4d6;
#         }#T_81340_row5_col4{
#             background-color:  #f2efef;
#         }#T_81340_row5_col5{
#             background-color:  #cde0d7;
#         }#T_81340_row5_col8{
#             background-color:  #edc7ca;
#         }#T_81340_row6_col1,#T_81340_row6_col7{
#             background-color:  #eecfd1;
#         }#T_81340_row6_col2{
#             background-color:  #ebbdc1;
#         }#T_81340_row6_col3,#T_81340_row7_col6,#T_81340_row8_col4{
#             background-color:  #edc9cb;
#         }#T_81340_row6_col4{
#             background-color:  #f2ebeb;
#         }#T_81340_row6_col5{
#             background-color:  #f0dedf;
#         }#T_81340_row6_col6{
#             background-color:  #d9e7e0;
#         }#T_81340_row7_col0{
#             background-color:  #e58f95;
#         }#T_81340_row7_col3{
#             background-color:  #ecc0c3;
#         }#T_81340_row7_col4{
#             background-color:  #eab6ba;
#         }#T_81340_row7_col7{
#             background-color:  #e9f1ed;
#         }#T_81340_row7_col8,#T_81340_row8_col5{
#             background-color:  #edcacd;
#         }#T_81340_row8_col0{
#             background-color:  #eab0b5;
#         }#T_81340_row8_col1{
#             background-color:  #eed1d3;
#         }#T_81340_row8_col2{
#             background-color:  #ecc3c6;
#         }#T_81340_row8_col8{
#             background-color:  #a4c6b6;
#         }</style><table id="T_81340_" style="font-family: CMU Serif; font-size:26px"><thead>    <tr>        <th class="index_name level0" >Adapt.</th>        <th class="col_heading level0 col0" >17-04</th>        <th class="col_heading level0 col1" >17-08</th>        <th class="col_heading level0 col2" >17-12</th>        <th class="col_heading level0 col3" >18-04</th>        <th class="col_heading level0 col4" >18-08</th>        <th class="col_heading level0 col5" >18-12</th>        <th class="col_heading level0 col6" >19-04</th>        <th class="col_heading level0 col7" >19-08</th>        <th class="col_heading level0 col8" >19-12</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_81340_level0_row0" class="row_heading level0 row0" >17-04</th>
#                         <td id="T_81340_row0_col0" class="data row0 col0" >-0.56</td>
#                         <td id="T_81340_row0_col1" class="data row0 col1" >0.53</td>
#                         <td id="T_81340_row0_col2" class="data row0 col2" >2.10</td>
#                         <td id="T_81340_row0_col3" class="data row0 col3" >3.24</td>
#                         <td id="T_81340_row0_col4" class="data row0 col4" >4.29</td>
#                         <td id="T_81340_row0_col5" class="data row0 col5" >5.37</td>
#                         <td id="T_81340_row0_col6" class="data row0 col6" >4.34</td>
#                         <td id="T_81340_row0_col7" class="data row0 col7" >5.19</td>
#                         <td id="T_81340_row0_col8" class="data row0 col8" >5.74</td>
#             </tr>
#             <tr>
#                         <th id="T_81340_level0_row1" class="row_heading level0 row1" >17-08</th>
#                         <td id="T_81340_row1_col0" class="data row1 col0" >0.52</td>
#                         <td id="T_81340_row1_col1" class="data row1 col1" >-1.62</td>
#                         <td id="T_81340_row1_col2" class="data row1 col2" >1.96</td>
#                         <td id="T_81340_row1_col3" class="data row1 col3" >2.89</td>
#                         <td id="T_81340_row1_col4" class="data row1 col4" >1.98</td>
#                         <td id="T_81340_row1_col5" class="data row1 col5" >4.58</td>
#                         <td id="T_81340_row1_col6" class="data row1 col6" >4.05</td>
#                         <td id="T_81340_row1_col7" class="data row1 col7" >3.20</td>
#                         <td id="T_81340_row1_col8" class="data row1 col8" >4.87</td>
#             </tr>
#             <tr>
#                         <th id="T_81340_level0_row2" class="row_heading level0 row2" >17-12</th>
#                         <td id="T_81340_row2_col0" class="data row2 col0" >1.48</td>
#                         <td id="T_81340_row2_col1" class="data row2 col1" >0.42</td>
#                         <td id="T_81340_row2_col2" class="data row2 col2" >-0.87</td>
#                         <td id="T_81340_row2_col3" class="data row2 col3" >1.05</td>
#                         <td id="T_81340_row2_col4" class="data row2 col4" >1.50</td>
#                         <td id="T_81340_row2_col5" class="data row2 col5" >2.61</td>
#                         <td id="T_81340_row2_col6" class="data row2 col6" >2.26</td>
#                         <td id="T_81340_row2_col7" class="data row2 col7" >2.65</td>
#                         <td id="T_81340_row2_col8" class="data row2 col8" >2.24</td>
#             </tr>
#             <tr>
# -1.0309416512516774

# %%
df = results_on_month("reddit", BASELINE_MODEL="bert-rand_1m")# MONTH_FILTER = ["04", "08", "12"])
# Out:
# <style  type="text/css" >
# #T_b2172_row0_col0{
#             background-color:  #a9c9bb;
#         }#T_b2172_row0_col1,#T_b2172_row20_col21,#T_b2172_row22_col21,#T_b2172_row22_col26{
#             background-color:  #f1eaea;
#         }#T_b2172_row0_col2{
#             background-color:  #d4e4dd;
#         }#T_b2172_row0_col3,#T_b2172_row9_col8,#T_b2172_row15_col14,#T_b2172_row26_col25{
#             background-color:  #e5eeea;
#         }#T_b2172_row0_col4,#T_b2172_row10_col9,#T_b2172_row12_col11,#T_b2172_row30_col32{
#             background-color:  #e8f0ec;
#         }#T_b2172_row0_col5,#T_b2172_row7_col8,#T_b2172_row10_col15,#T_b2172_row12_col9,#T_b2172_row14_col5,#T_b2172_row16_col10,#T_b2172_row18_col9,#T_b2172_row18_col16,#T_b2172_row19_col20,#T_b2172_row20_col26,#T_b2172_row26_col20,#T_b2172_row26_col27,#T_b2172_row27_col15,#T_b2172_row28_col32{
#             background-color:  #efdadb;
#         }#T_b2172_row0_col6,#T_b2172_row8_col16,#T_b2172_row10_col1,#T_b2172_row10_col18,#T_b2172_row11_col7,#T_b2172_row12_col6,#T_b2172_row14_col1,#T_b2172_row16_col6,#T_b2172_row16_col8,#T_b2172_row17_col0,#T_b2172_row19_col17,#T_b2172_row20_col4,#T_b2172_row20_col27,#T_b2172_row21_col8,#T_b2172_row22_col0,#T_b2172_row23_col2,#T_b2172_row24_col4,#T_b2172_row24_col15,#T_b2172_row26_col3,#T_b2172_row26_col4,#T_b2172_row26_col14,#T_b2172_row27_col6,#T_b2172_row27_col13,#T_b2172_row28_col19,#T_b2172_row29_col31,#T_b2172_row30_col19,#T_b2172_row35_col26{
#             background-color:  #edcacd;
#         }#T_b2172_row0_col7,#T_b2172_row0_col11,#T_b2172_row0_col16,#T_b2172_row8_col21,#T_b2172_row11_col1,#T_b2172_row11_col29,#T_b2172_row14_col27,#T_b2172_row14_col32,#T_b2172_row15_col24,#T_b2172_row23_col1,#T_b2172_row29_col4,#T_b2172_row31_col7,#T_b2172_row31_col10,#T_b2172_row31_col14,#T_b2172_row34_col20,#T_b2172_row34_col28,#T_b2172_row34_col30,#T_b2172_row35_col18,#T_b2172_row35_col19,#T_b2172_row35_col20,#T_b2172_row35_col24{
#             background-color:  #e9abaf;
#         }#T_b2172_row0_col8,#T_b2172_row2_col16,#T_b2172_row3_col16,#T_b2172_row7_col33,#T_b2172_row8_col33,#T_b2172_row8_col34,#T_b2172_row11_col18,#T_b2172_row12_col23,#T_b2172_row12_col24,#T_b2172_row15_col32,#T_b2172_row32_col0,#T_b2172_row33_col12,#T_b2172_row34_col23,#T_b2172_row34_col27,#T_b2172_row35_col10{
#             background-color:  #e8a4a9;
#         }#T_b2172_row0_col9,#T_b2172_row4_col7,#T_b2172_row13_col29,#T_b2172_row15_col33,#T_b2172_row16_col19,#T_b2172_row16_col24,#T_b2172_row20_col35,#T_b2172_row26_col7,#T_b2172_row29_col3,#T_b2172_row29_col6,#T_b2172_row30_col6,#T_b2172_row30_col7,#T_b2172_row31_col17,#T_b2172_row32_col9,#T_b2172_row34_col31,#T_b2172_row34_col32{
#             background-color:  #ebb8bb;
#         }#T_b2172_row0_col10,#T_b2172_row9_col25,#T_b2172_row10_col33,#T_b2172_row11_col2,#T_b2172_row11_col24,#T_b2172_row12_col25,#T_b2172_row13_col34,#T_b2172_row15_col28,#T_b2172_row16_col28,#T_b2172_row17_col1,#T_b2172_row19_col34,#T_b2172_row29_col9,#T_b2172_row29_col17,#T_b2172_row31_col6,#T_b2172_row35_col16,#T_b2172_row35_col25{
#             background-color:  #eab3b7;
#         }#T_b2172_row0_col12,#T_b2172_row1_col15,#T_b2172_row2_col12,#T_b2172_row6_col21,#T_b2172_row6_col22,#T_b2172_row8_col23,#T_b2172_row29_col1,#T_b2172_row32_col1{
#             background-color:  #e58f95;
#         }#T_b2172_row0_col13,#T_b2172_row2_col8,#T_b2172_row4_col17,#T_b2172_row4_col19,#T_b2172_row8_col24,#T_b2172_row11_col19{
#             background-color:  #e6979d;
#         }#T_b2172_row0_col14,#T_b2172_row3_col14,#T_b2172_row4_col18,#T_b2172_row6_col17,#T_b2172_row8_col31,#T_b2172_row8_col32,#T_b2172_row13_col28,#T_b2172_row19_col1,#T_b2172_row34_col13,#T_b2172_row35_col7{
#             background-color:  #e79ca2;
#         }#T_b2172_row0_col15,#T_b2172_row1_col13,#T_b2172_row5_col14,#T_b2172_row5_col17,#T_b2172_row7_col25,#T_b2172_row8_col29,#T_b2172_row9_col19,#T_b2172_row9_col23,#T_b2172_row9_col27,#T_b2172_row9_col35,#T_b2172_row10_col27,#T_b2172_row10_col31,#T_b2172_row11_col22,#T_b2172_row11_col25,#T_b2172_row12_col22,#T_b2172_row12_col30,#T_b2172_row13_col30,#T_b2172_row15_col27,#T_b2172_row15_col30,#T_b2172_row30_col5,#T_b2172_row35_col21{
#             background-color:  #e8a5aa;
#         }#T_b2172_row0_col17,#T_b2172_row0_col19,#T_b2172_row2_col15,#T_b2172_row4_col28,#T_b2172_row6_col19,#T_b2172_row7_col28,#T_b2172_row7_col35,#T_b2172_row8_col35,#T_b2172_row33_col1{
#             background-color:  #e58d94;
#         }#T_b2172_row0_col18,#T_b2172_row0_col21,#T_b2172_row1_col14,#T_b2172_row5_col21,#T_b2172_row6_col26,#T_b2172_row8_col27,#T_b2172_row11_col32{
#             background-color:  #e58b91;
#         }#T_b2172_row0_col20,#T_b2172_row4_col29,#T_b2172_row5_col24,#T_b2172_row6_col29,#T_b2172_row6_col30{
#             background-color:  #e27880;
#         }#T_b2172_row0_col22,#T_b2172_row0_col25,#T_b2172_row6_col31,#T_b2172_row6_col34,#T_b2172_row34_col0,#T_b2172_row35_col1{
#             background-color:  #e38188;
#         }#T_b2172_row0_col23,#T_b2172_row0_col32,#T_b2172_row5_col35{
#             background-color:  #de5b65;
#         }#T_b2172_row0_col24,#T_b2172_row1_col21,#T_b2172_row3_col30,#T_b2172_row34_col1{
#             background-color:  #e16e77;
#         }#T_b2172_row0_col26,#T_b2172_row0_col31,#T_b2172_row2_col34{
#             background-color:  #e0656f;
#         }#T_b2172_row0_col27,#T_b2172_row2_col23,#T_b2172_row3_col34,#T_b2172_row5_col31{
#             background-color:  #e06a73;
#         }#T_b2172_row0_col28,#T_b2172_row0_col35{
#             background-color:  #de5a64;
#         }#T_b2172_row0_col29,#T_b2172_row1_col28,#T_b2172_row1_col33,#T_b2172_row1_col34{
#             background-color:  #dd515c;
#         }#T_b2172_row0_col30,#T_b2172_row3_col23,#T_b2172_row6_col24{
#             background-color:  #e2757d;
#         }#T_b2172_row0_col33,#T_b2172_row1_col18,#T_b2172_row2_col25{
#             background-color:  #e2747c;
#         }#T_b2172_row0_col34,#T_b2172_row1_col25{
#             background-color:  #df646d;
#         }#T_b2172_row1_col0,#T_b2172_row1_col5,#T_b2172_row2_col5,#T_b2172_row4_col0,#T_b2172_row13_col11,#T_b2172_row14_col11,#T_b2172_row23_col26,#T_b2172_row29_col30{
#             background-color:  #f2ebeb;
#         }#T_b2172_row1_col1{
#             background-color:  #8db7a4;
#         }#T_b2172_row1_col2,#T_b2172_row16_col15,#T_b2172_row31_col33{
#             background-color:  #e9f1ed;
#         }#T_b2172_row1_col3,#T_b2172_row2_col0,#T_b2172_row2_col4,#T_b2172_row3_col0,#T_b2172_row5_col2,#T_b2172_row9_col2,#T_b2172_row10_col2,#T_b2172_row17_col20,#T_b2172_row20_col15,#T_b2172_row23_col21,#T_b2172_row25_col22,#T_b2172_row27_col30,#T_b2172_row30_col31,#T_b2172_row31_col29{
#             background-color:  #f0e3e3;
#         }#T_b2172_row1_col4,#T_b2172_row1_col6,#T_b2172_row8_col10,#T_b2172_row9_col6,#T_b2172_row12_col15,#T_b2172_row14_col7,#T_b2172_row17_col21,#T_b2172_row18_col21,#T_b2172_row19_col21,#T_b2172_row21_col32,#T_b2172_row23_col20,#T_b2172_row24_col20,#T_b2172_row29_col33,#T_b2172_row33_col25{
#             background-color:  #f0ddde;
#         }#T_b2172_row1_col7,#T_b2172_row6_col11,#T_b2172_row7_col22,#T_b2172_row9_col31,#T_b2172_row31_col12,#T_b2172_row33_col5,#T_b2172_row33_col10,#T_b2172_row35_col3{
#             background-color:  #e8a1a6;
#         }#T_b2172_row1_col8,#T_b2172_row1_col11,#T_b2172_row11_col20,#T_b2172_row11_col23,#T_b2172_row34_col3,#T_b2172_row34_col17{
#             background-color:  #e58c93;
#         }#T_b2172_row1_col9,#T_b2172_row6_col13,#T_b2172_row7_col24,#T_b2172_row10_col20,#T_b2172_row10_col26,#T_b2172_row10_col34,#T_b2172_row11_col0,#T_b2172_row13_col23,#T_b2172_row14_col35,#T_b2172_row15_col23,#T_b2172_row24_col1,#T_b2172_row28_col12,#T_b2172_row29_col0,#T_b2172_row31_col2,#T_b2172_row31_col3,#T_b2172_row31_col8{
#             background-color:  #e9a9ae;
#         }#T_b2172_row1_col10,#T_b2172_row5_col8,#T_b2172_row5_col15,#T_b2172_row5_col16,#T_b2172_row7_col29,#T_b2172_row8_col20,#T_b2172_row9_col34,#T_b2172_row10_col29,#T_b2172_row12_col32,#T_b2172_row13_col27,#T_b2172_row13_col32,#T_b2172_r

# %%
# test whether models perform better on past than on future

def wilcoxon_assymetry(df):
    
    x=np.empty(0)
    y=np.empty(0)
    
    for k in range(1,df.shape[0]):
        x = np.append(x, np.diag(df, k=k))
        y = np.append(y, np.diag(df, k=-k))
    
    dif = x-y
    print(dif.mean())
    
    return wilcoxon(x=x, y=y, alternative="greater")

wilcoxon_assymetry(df)
# Out:
# 0.7769864840908813
# WilcoxonResult(statistic=171004.0, pvalue=1.1873210639523903e-55)

# %% [markdown]
# # Cumu Model Results
# Reddit only

# %%
# load three series of pseudo-perplexities:
plot_series = {}


# 1. model adapted to first month (2017_03_1m)
plot_series["first month"] = {}

for key in sorted(perplexity["reddit"]["test-on-month"]):
    if "bert-2017_03_1m" in key:
        plot_series["first month"][re.search(r"(.*?)-test_20(.*)_10k",key).group(2).replace("_", "/")] = perplexity["reddit"]["test-on-month"][key]
     
    
# 2. models adapted to current month
plot_series["test month"] = {}

for key in sorted(perplexity["reddit"]["test-on-month"]):
    if re.search(r"bert-(.*?)_1m-(.*)", key).group(1) == re.search(r"(.*?)test_(.*?)_10k(.*)", key).group(2):
        plot_series["test month"][re.search(r"(.*?)-test_20(.*)_10k",key).group(2).replace("_", "/")] = perplexity["reddit"]["test-on-month"][key]
    

# 3. cumulative models adapted to months up to and including current month
plot_series["cumu. month"] = {}

for key in sorted(perplexity["reddit"]["cumu-test"]):
    if re.search(r"bert-cumu_(.*?)_1m-(.*)", key).group(1) == re.search(r"(.*?)test_(.*?)_10k(.*)", key).group(2):
        plot_series["cumu. month"][re.search(r"(.*?)-test_20(.*)_10k",key).group(2).replace("_", "/")] = perplexity["reddit"]["cumu-test"][key]

    
# write to df
plot_df = pd.DataFrame.from_dict(plot_series)

# load baseline series for normalisation
baseline_series = {}

for key in sorted(perplexity["reddit"]["test-on-month"]):
        if "bert-rand_1m" in key:
            baseline_series[re.search(r"(.*?)-test_20(.*)_10k",key).group(2).replace("_", "/")] = perplexity["reddit"]["test-on-month"][key]

# divide each column in df by baseline series
for column in plot_df.columns:
    plot_df[column] = plot_df[column].divide(pd.Series(baseline_series), axis=0)-1

# %%
# create plot from plot_df

fig, ax = plt.subplots(figsize = (10,7))

ax.plot(plot_df)
loc = plticker.MultipleLocator(base=4.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)

# set labels for x and y axis
plt.xlabel('Test Month', fontsize=24, fontname="CMU Serif")
plt.ylabel('Relative Pseudo-Perplexity (%)', fontsize=24, fontname="CMU Serif")

# set the font for axis tick labels to be CMU Serif
matplotlib.rcParams['axes.unicode_minus'] = False
for tick in ax.get_xticklabels():
    tick.set_fontname("CMU Serif")
for tick in ax.get_yticklabels():
    tick.set_fontname("CMU Serif")

# set tick font size
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# change y axis to percent, without the % symbol    
ax.yaxis.set_major_formatter(plticker.PercentFormatter(1.0, symbol=""))

# add horizontal line at 0
plt.hlines(0, xmin="17/03", xmax="20/02", colors="grey", linestyles="dashed")

# cut off x axis at first and last month
ax.set_xlim(left="17/03", right = "20/02")

# create legend
font = font_manager.FontProperties(family='CMU Serif',style='normal', size=20)
lines, labels = plot_df.plot().get_legend_handles_labels()
ax.legend(lines, labels, loc='best', facecolor='white', framealpha=1, fontsize=20, prop = font)

plt.show()
